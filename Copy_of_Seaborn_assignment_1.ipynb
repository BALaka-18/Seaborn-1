# %% [markdown]
# <a href="https://colab.research.google.com/github/BALaka-18/Seaborn-1/blob/master/Copy_of_Seaborn_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib as ml
import matplotlib.pyplot as plt
# %matplotlib inline
ml.style.use('fivethirtyeight')

# %%
data=sns.load_dataset('titanic')

# %%
data.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
data[data['embark_town'].isnull()==True]
# Out:
#      survived  pclass     sex   age  ...  adult_male  embark_town  alive alone
# 61          1       1  female  38.0  ...       False          NaN    yes  True
# 829         1       1  female  62.0  ...       False          NaN    yes  True
#
# [2 rows x 14 columns]

# %%
data.age.fillna(np.mean(data.age),inplace=True)
data.drop(['deck'],axis=1,inplace=True)
data.drop(index=[61,829],inplace=True)

# %%
data.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
# Problem 1 : Plot a Heatmap on the correlation between multiple columns

sns.heatmap(data.corr(),annot=True,linewidths=0.1,linecolor='white')
plt.show()

# %%
# Problem 2 : Plot the distribution of age column using a Boxplot on the basis of sex column

sns.boxplot(x=data.age,data=data,hue=data.sex,color='yellow')
plt.show()

# %%
# Problem 3 : Plot the distribution of age using a ViolinPlot on the basis of both Pclass and Sex column

plt.figure(figsize=(20,10))
sns.violinplot(x=data.age,y=data.sex,data=data,hue=data.pclass)
plt.show()

# %%
data.shape
# Out:
# (889, 14)

# %%
data.survived.value_counts()
# Out:
# 0    549
# 1    340
# Name: survived, dtype: int64

# %%
# Problem 4 : Plot the count of Survivors and Non-Survivors

sns.countplot(x=data.survived,data=data)
plt.show()

# %%
# Problem 5: Plot the count of survivors as well as non-survivors on the basis of Pclass

sns.countplot(x=data.survived,data=data,hue=data.pclass)
plt.show()

# %%
# Problem 6: Plot a scatterplot between age and fare column on the basis of both Pclass and Sex column

plt.figure(figsize=(10,5))
sns.scatterplot(x=data.age,y=data.fare,data=data,hue=data.sex)
plt.title('On the basis of Sex')
plt.show()
print("\n")
plt.figure(figsize=(20,10))
sns.scatterplot(x=data.age,y=data.fare,data=data,hue=data.pclass,palette=['green','red','blue'])
plt.title('On the basis of Pclass')
plt.show()
